# %%
import os
import json
import glob
import torch
import re
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go
import plotly.io as pio
#import seaborn as sns
import matplotlib.pyplot as plt
from utils.data_processing import (
    load_edge_scores_into_dictionary,
    get_ckpts,
    load_metrics,
    compute_ged,
    compute_weighted_ged,
    compute_gtd,
    compute_jaccard_similarity_to_reference,
    compute_jaccard_similarity,
    aggregate_metrics_to_tensors_step_number,
    get_ckpts
)

# %%
def read_json_file(file_path):
    with open(file_path, 'r') as file:
        return json.load(file)



def load_nodes_into_dictionary(folder_path):
    file_paths = glob.glob(f'{folder_path}/*.json')

    # Create an empty DataFrame to store all edge scores
    all_nodes = pd.DataFrame()

    for i, file_path in enumerate(file_paths):
        print(f'Processing file {i+1}/{len(file_paths)}: {file_path}')
        data = read_json_file(file_path)
        nodes = data['nodes']
        node_names = list(nodes.keys())
        circuit_inclusion = [status for status in nodes.values()]

        # Extract checkpoint name from the filename
        checkpoint_name = int(os.path.basename(file_path).replace('.json', ''))
        #checkpoint_name = f'step {checkpoint_name}'

        checkpoint_df = pd.DataFrame({'node': node_names, 'in_circuit': circuit_inclusion, 'checkpoint': checkpoint_name})
        all_nodes = pd.concat([all_nodes, checkpoint_df])

    all_nodes = all_nodes.sort_values('checkpoint')
    return all_nodes

# %%
folder_path = 'results/graphs/pythia-160m/ioi'

node_df = load_nodes_into_dictionary(folder_path)
edge_df = load_edge_scores_into_dictionary(folder_path)

node_df = node_df[node_df['checkpoint'] >= 4000]
edge_df = edge_df[edge_df['checkpoint'] >= 4000]
edge_df = edge_df[edge_df['checkpoint'] <= 78000]
# Out:
# Processing file 1/97: results/graphs/pythia-160m/ioi/57000.json
# Processing file 2/97: results/graphs/pythia-160m/ioi/34000.json
# Processing file 3/97: results/graphs/pythia-160m/ioi/6000.json
# Processing file 4/97: results/graphs/pythia-160m/ioi/37000.json
# Processing file 5/97: results/graphs/pythia-160m/ioi/39000.json
# Processing file 6/97: results/graphs/pythia-160m/ioi/59000.json
# Processing file 7/97: results/graphs/pythia-160m/ioi/67000.json
# Processing file 8/97: results/graphs/pythia-160m/ioi/16.json
# Processing file 9/97: results/graphs/pythia-160m/ioi/76000.json
# Processing file 10/97: results/graphs/pythia-160m/ioi/1.json
# Processing file 11/97: results/graphs/pythia-160m/ioi/5000.json
# Processing file 12/97: results/graphs/pythia-160m/ioi/42000.json
# Processing file 13/97: results/graphs/pythia-160m/ioi/77000.json
# Processing file 14/97: results/graphs/pythia-160m/ioi/80000.json
# Processing file 15/97: results/graphs/pythia-160m/ioi/63000.json
# Processing file 16/97: results/graphs/pythia-160m/ioi/56000.json
# Processing file 17/97: results/graphs/pythia-160m/ioi/8000.json
# Processing file 18/97: results/graphs/pythia-160m/ioi/120000.json
# Processing file 19/97: results/graphs/pythia-160m/ioi/62000.json
# Processing file 20/97: results/graphs/pythia-160m/ioi/70000.json
# Processing file 21/97: results/graphs/pythia-160m/ioi/19000.json
# Processing file 22/97: results/graphs/pythia-160m/ioi/2000.json
# Processing file 23/97: results/graphs/pythia-160m/ioi/143000.json
# Processing file 24/97: results/graphs/pythia-160m/ioi/79000.json
# Processing file 25/97: results/graphs/pythia-160m/ioi/29000.json
# Processing file 26/97: results/graphs/pythia-160m/ioi/10000.json
# Processing file 27/97: results/graphs/pythia-160m/ioi/65000.json
# Processing file 28/97: results/graphs/pythia-160m/ioi/60000.json
# Processing file 29/97: results/graphs/pythia-160m/ioi/90000.json
# Processing file 30/97: results/graphs/pythia-160m/ioi/1000.json
# Processing file 31/97: results/graphs/pythia-160m/ioi/33000.json
# Processing file 32/97: results/graphs/pythia-160m/ioi/35000.json
# Processing file 33/97: results/graphs/pythia-160m/ioi/18000.json
# Processing file 34/97: results/graphs/pythia-160m/ioi/4.json
# Processing file 35/97: results/graphs/pythia-160m/ioi/55000.json
# Processing file 36/97: results/graphs/pythia-160m/ioi/49000.json
# Processing file 37/97: results/graphs/pythia-160m/ioi/130000.json
# Processing file 38/97: results/graphs/pythia-160m/ioi/31000.json
# Processing file 39/97: results/graphs/pythia-160m/ioi/46000.json
# Processing file 40/97: results/graphs/pythia-160m/ioi/26000.json
# Processing file 41/97: results/graphs/pythia-160m/ioi/78000.json
# Processing file 42/97: results/graphs/pythia-160m/ioi/13000.json
# Processing file 43/97: results/graphs/pythia-160m/ioi/47000.json
# Processing file 44/97: results/graphs/pythia-160m/ioi/58000.json
# Processing file 45/97: results/graphs/pythia-160m/ioi/32.json
# Processing file 46/97: results/graphs/pythia-160m/ioi/128.json
# Processing file 47/97: results/graphs/pythia-160m/ioi/100000.json
# Processing file 48/97: results/graphs/pythia-160m/ioi/27000.json
# Processing file 49/97: results/graphs/pythia-160m/ioi/48000.json
# Processing file 50/97: results/graphs/pythia-160m/ioi/32000.json
# Processing file 51/97: results/graphs/pythia-160m/ioi/30000.json
# Processing file 52/97: results/graphs/pythia-160m/ioi/44000.json
# Processing file 53/97: results/graphs/pythia-160m/ioi/74000.json
# Processing file 54/97: results/graphs/pythia-160m/ioi/64000.json
# Processing file 55/97: results/graphs/pythia-160m/ioi/2.json
# Processing file 56/97: results/graphs/pythia-160m/ioi/69000.json
# Processing file 57/97: results/graphs/pythia-160m/ioi/140000.json
# Processing file 58/97: results/graphs/pythia-160m/ioi/72000.json
# Processing file 59/97: results/graphs/pythia-160m/ioi/9000.json
# Processing file 60/97: results/graphs/pythia-160m/ioi/110000.json
# Processing file 61/97: results/graphs/pythia-160m/ioi/16000.json
# Processing file 62/97: results/graphs/pythia-160m/ioi/23000.json
# Processing file 63/97: results/graphs/pythia-160m/ioi/22000.json
# Processing file 64/97: results/graphs/pythia-160m/ioi/17000.json
# Processing file 65/97: results/graphs/pythia-160m/ioi/73000.json
# Processing file 66/97: results/graphs/pythia-160m/ioi/3000.json
# Processing file 67/97: results/graphs/pythia-160m/ioi/71000.json
# Processing file 68/97: results/graphs/pythia-160m/ioi/24000.json
# Processing file 69/97: results/graphs/pythia-160m/ioi/51000.json
# Processing file 70/97: results/graphs/pythia-160m/ioi/52000.json
# Processing file 71/97: results/graphs/pythia-160m/ioi/40000.json
# Processing file 72/97: results/graphs/pythia-160m/ioi/8.json
# Processing file 73/97: results/graphs/pythia-160m/ioi/43000.json
# Processing file 74/97: results/graphs/pythia-160m/ioi/54000.json
# Processing file 75/97: results/graphs/pythia-160m/ioi/11000.json
# Processing file 76/97: results/graphs/pythia-160m/ioi/36000.json
# Processing file 77/97: results/graphs/pythia-160m/ioi/45000.json
# Processing file 78/97: results/graphs/pythia-160m/ioi/50000.json
# Processing file 79/97: results/graphs/pythia-160m/ioi/64.json
# Processing file 80/97: results/graphs/pythia-160m/ioi/66000.json
# Processing file 81/97: results/graphs/pythia-160m/ioi/28000.json
# Processing file 82/97: results/graphs/pythia-160m/ioi/14000.json
# Processing file 83/97: results/graphs/pythia-160m/ioi/75000.json
# Processing file 84/97: results/graphs/pythia-160m/ioi/12000.json
# Processing file 85/97: results/graphs/pythia-160m/ioi/256.json
# Processing file 86/97: results/graphs/pythia-160m/ioi/21000.json
# Processing file 87/97: results/graphs/pythia-160m/ioi/38000.json
# Processing file 88/97: results/graphs/pythia-160m/ioi/15000.json
# Processing file 89/97: results/graphs/pythia-160m/ioi/61000.json
# Processing file 90/97: results/graphs/pythia-160m/ioi/7000.json
# Processing file 91/97: results/graphs/pythia-160m/ioi/512.json
# Processing file 92/97: results/graphs/pythia-160m/ioi/68000.json
# Processing file 93/97: results/graphs/pythia-160m/ioi/53000.json
# Processing file 94/97: results/graphs/pythia-160m/ioi/25000.json
# Processing file 95/97: results/graphs/pythia-160m/ioi/4000.json
# Processing file 96/97: results/graphs/pythia-160m/ioi/20000.json
# Processing file 97/97: results/graphs/pythia-160m/ioi/41000.json
# Processing file 1/97: results/graphs/pythia-160m/ioi/57000.json
# Processing file 2/97: results/graphs/pythia-160m/ioi/34000.json
# Processing file 3/97: results/graphs/pythia-160m/ioi/6000.json
# Processing file 4/97: results/graphs/pythia-160m/ioi/37000.json
# Processing file 5/97: results/graphs/pythia-160m/ioi/39000.json
# Processing file 6/97: results/graphs/pythia-160m/ioi/59000.json
# Processing file 7/97: results/graphs/pythia-160m/ioi/67000.json
# Processing file 8/97: results/graphs/pythia-160m/ioi/16.json
# Processing file 9/97: results/graphs/pythia-160m/ioi/76000.json
# Processing file 10/97: results/graphs/pythia-160m/ioi/1.json
# Processing file 11/97: results/graphs/pythia-160m/ioi/5000.json
# Processing file 12/97: results/graphs/pythia-160m/ioi/42000.json
# Processing file 13/97: results/graphs/pythia-160m/ioi/77000.json
# Processing file 14/97: results/graphs/pythia-160m/ioi/80000.json
# Processing file 15/97: results/graphs/pythia-160m/ioi/63000.json
# Processing file 16/97: results/graphs/pythia-160m/ioi/56000.json
# Processing file 17/97: results/graphs/pythia-160m/ioi/8000.json
# Processing file 18/97: results/graphs/pythia-160m/ioi/120000.json
# Processing file 19/97: results/graphs/pythia-160m/ioi/62000.json
# Processing file 20/97: results/graphs/pythia-160m/ioi/70000.json
# Processing file 21/97: results/graphs/pythia-160m/ioi/19000.json
# Processing file 22/97: results/graphs/pythia-160m/ioi/2000.json
# Processing file 23/97: results/graphs/pythia-160m/ioi/143000.json
# Processing file 24/97: results/graphs/pythia-160m/ioi/79000.json
# Processing file 25/97: results/graphs/pythia-160m/ioi/29000.json
# Processing file 26/97: results/graphs/pythia-160m/ioi/10000.json
# Processing file 27/97: results/graphs/pythia-160m/ioi/65000.json
# Processing file 28/97: results/graphs/pythia-160m/ioi/60000.json
# Processing file 29/97: results/graphs/pythia-160m/ioi/90000.json
# Processing file 30/97: results/graphs/pythia-160m/ioi/1000.json
# Processing file 31/97: results/graphs/pythia-160m/ioi/33000.json
# Processing file 32/97: results/graphs/pythia-160m/ioi/35000.json
# Processing file 33/97: results/graphs/pythia-160m/ioi/18000.json
# Processing file 34/97: results/graphs/pythia-160m/ioi/4.json
# Processing file 35/97: results/graphs/pythia-160m/ioi/55000.json
# Processing file 36/97: results/graphs/pythia-160m/ioi/49000.json
# Processing file 37/97: results/graphs/pythia-160m/ioi/130000.json
# Processing file 38/97: results/graphs/pythia-160m/ioi/31000.json
# Processing file 39/97: results/graphs/pythia-160m/ioi/46000.json
# Processing file 40/97: results/graphs/pythia-160m/ioi/26000.json
# Processing file 41/97: results/graphs/pythia-160m/ioi/78000.json
# Processing file 42/97: results/graphs/pythia-160m/ioi/13000.json
# Processing file 43/97: results/graphs/pythia-160m/ioi/47000.json
# Processing file 44/97: results/graphs/pythia-160m/ioi/58000.json
# Processing file 45/97: results/graphs/pythia-160m/ioi/32.json
# Processing file 46/97: results/graphs/pythia-160m/ioi/128.json
# Processing file 47/97: results/graphs/pythia-160m/ioi/100000.json
# Processing file 48/97: results/graphs/pythia-160m/ioi/27000.json
# Processing file 49/97: results/graphs/pythia-160m/ioi/48000.json
# Processing file 50/97: results/graphs/pythia-160m/ioi/32000.json
# Processing file 51/97: results/graphs/pythia-160m/ioi/30000.json
# Processing file 52/97: results/graphs/pythia-160m/ioi/44000.json
# Processing file 53/97: results/graphs/pythia-160m/ioi/74000.json
# Processing file 54/97: results/graphs/pythia-160m/ioi/64000.json
# Processing file 55/97: results/graphs/pythia-160m/ioi/2.json
# Processing file 56/97: results/graphs/pythia-160m/ioi/69000.json
# Processing file 57/97: results/graphs/pythia-160m/ioi/140000.json
# Processing file 58/97: results/graphs/pythia-160m/ioi/72000.json
# Processing file 59/97: results/graphs/pythia-160m/ioi/9000.json
# Processing file 60/97: results/graphs/pythia-160m/ioi/110000.json
# Processing file 61/97: results/graphs/pythia-160m/ioi/16000.json
# Processing file 62/97: results/graphs/pythia-160m/ioi/23000.json
# Processing file 63/97: results/graphs/pythia-160m/ioi/22000.json
# Processing file 64/97: results/graphs/pythia-160m/ioi/17000.json
# Processing file 65/97: results/graphs/pythia-160m/ioi/73000.json
# Processing file 66/97: results/graphs/pythia-160m/ioi/3000.json
# Processing file 67/97: results/graphs/pythia-160m/ioi/71000.json
# Processing file 68/97: results/graphs/pythia-160m/ioi/24000.json
# Processing file 69/97: results/graphs/pythia-160m/ioi/51000.json
# Processing file 70/97: results/graphs/pythia-160m/ioi/52000.json
# Processing file 71/97: results/graphs/pythia-160m/ioi/40000.json
# Processing file 72/97: results/graphs/pythia-160m/ioi/8.json
# Processing file 73/97: results/graphs/pythia-160m/ioi/43000.json
# Processing file 74/97: results/graphs/pythia-160m/ioi/54000.json
# Processing file 75/97: results/graphs/pythia-160m/ioi/11000.json
# Processing file 76/97: results/graphs/pythia-160m/ioi/36000.json
# Processing file 77/97: results/graphs/pythia-160m/ioi/45000.json
# Processing file 78/97: results/graphs/pythia-160m/ioi/50000.json
# Processing file 79/97: results/graphs/pythia-160m/ioi/64.json
# Processing file 80/97: results/graphs/pythia-160m/ioi/66000.json
# Processing file 81/97: results/graphs/pythia-160m/ioi/28000.json
# Processing file 82/97: results/graphs/pythia-160m/ioi/14000.json
# Processing file 83/97: results/graphs/pythia-160m/ioi/75000.json
# Processing file 84/97: results/graphs/pythia-160m/ioi/12000.json
# Processing file 85/97: results/graphs/pythia-160m/ioi/256.json
# Processing file 86/97: results/graphs/pythia-160m/ioi/21000.json
# Processing file 87/97: results/graphs/pythia-160m/ioi/38000.json
# Processing file 88/97: results/graphs/pythia-160m/ioi/15000.json
# Processing file 89/97: results/graphs/pythia-160m/ioi/61000.json
# Processing file 90/97: results/graphs/pythia-160m/ioi/7000.json
# Processing file 91/97: results/graphs/pythia-160m/ioi/512.json
# Processing file 92/97: results/graphs/pythia-160m/ioi/68000.json
# Processing file 93/97: results/graphs/pythia-160m/ioi/53000.json
# Processing file 94/97: results/graphs/pythia-160m/ioi/25000.json
# Processing file 95/97: results/graphs/pythia-160m/ioi/4000.json
# Processing file 96/97: results/graphs/pythia-160m/ioi/20000.json
# Processing file 97/97: results/graphs/pythia-160m/ioi/41000.json

# %%
# get unique edges
edge_df[['source', 'target']] = edge_df['edge'].str.split('->', expand=True)
len(edge_df['target'].unique())
# Out:
# 445

# %%
# normalize edge scores for each checkpoint. edge_df has the following columns: edge, score, in_circuit, checkpoint
# edge scores should be normalized by the sum of edge scores for each checkpoint
# only sum scores for edges where in_circuit is True
# Normalize scores by the sum of scores for each checkpoint
edge_df['normalized_score'] = edge_df.groupby('checkpoint')['score'].transform(lambda x: x / x.sum())

edge_df.head(10)
# Out:
#                    edge         score  in_circuit  checkpoint  source  \
# 10784  a0.h10->a7.h5<v>  2.473593e-06       False        4000  a0.h10
# 10783  a0.h10->a7.h5<k>  3.635883e-06       False        4000  a0.h10
# 10782  a0.h10->a7.h5<q> -2.369285e-06       False        4000  a0.h10
# 10774  a0.h10->a7.h2<k> -5.550683e-07       False        4000  a0.h10
# 10781  a0.h10->a7.h4<v> -4.544854e-07       False        4000  a0.h10
# 10778  a0.h10->a7.h3<v> -4.544854e-07       False        4000  a0.h10
# 10779  a0.h10->a7.h4<q>  5.252659e-07       False        4000  a0.h10
# 10777  a0.h10->a7.h3<k>  3.306195e-08       False        4000  a0.h10
# 10776  a0.h10->a7.h3<q>  4.991889e-07       False        4000  a0.h10
# 10775  a0.h10->a7.h2<v>  1.117587e-06       False        4000  a0.h10
#
#          target  normalized_score
# 10784  a7.h5<v>      1.567943e-05
# 10783  a7.h5<k>      2.304687e-05
# 10782  a7.h5<q>     -1.501825e-05
# 10774  a7.h2<k>     -3.518426e-06
# 10781  a7.h4<v>     -2.880859e-06
# 10778  a7.h3<v>     -2.880859e-06
# 10779  a7.h4<q>      3.329517e-06
# 10777  a7.h3<k>      2.095707e-07
# 10776  a7.h3<q>      3.164222e-06
# 10775  a7.h2<v>      7.084079e-06

# %%
# Sum the normalized scores for each source node
source_scores = edge_df.groupby(['source'])['normalized_score'].sum()
source_scores = source_scores.reset_index()
source_scores = source_scores.rename(columns={'source': 'node', 'normalized_score': 'source_score'})

# sort in descending order
source_scores = source_scores.sort_values('source_score', ascending=False)
source_scores.head(30)
# Out:
#         node  source_score
# 131    a8.h9     22.564401
# 144    input     21.913746
# 145       m0     19.913437
# 25    a10.h1      2.314663
# 75    a4.h11      2.256133
# 104    a6.h6      1.937911
# 149       m2      1.823485
# 112    a7.h2      1.300857
# 56     a2.h6      0.812817
# 103    a6.h5      0.798604
# 80     a4.h6      0.788679
# 150       m3      0.760130
# 33    a10.h7      0.607993
# 147      m10      0.539829
# 156       m9      0.482690
# 124    a8.h2      0.411208
# 119    a7.h9      0.399869
# 73     a4.h1      0.388624
# 82     a4.h8      0.360433
# 94     a5.h8      0.352457
# 148      m11      0.340147
# 142    a9.h8      0.263644
# 27   a10.h11      0.245369
# 140    a9.h6      0.242158
# 99    a6.h11      0.239591
# 84     a5.h0      0.219074
# 146       m1      0.218274
# 151       m4      0.211196
# 60     a3.h0      0.210453
# 44    a11.h6      0.189971

# %%
# for each checkpoint, how many unique sources are there? (filter by in_circuit==True)
unique_sources = edge_df[edge_df['in_circuit']==True].groupby('checkpoint')['source'].nunique()

# %%
unique_sources.head(40)
# Out:
# checkpoint
# 5000     16
# 6000     20
# 7000     16
# 8000     22
# 9000     17
# 10000    21
# 11000    34
# 12000    42
# 13000    48
# 14000    46
# 15000    38
# 16000    40
# 17000    39
# 18000    42
# 19000    43
# 20000    34
# 21000    54
# 22000    38
# 23000    38
# 24000    52
# 25000    42
# 26000    58
# 27000    44
# 28000    52
# 29000    43
# 30000    50
# 31000    42
# 32000    44
# 33000    49
# 34000    59
# 35000    48
# 36000    63
# 37000    37
# 38000    44
# 39000    53
# 40000    61
# 41000    60
# 42000    46
# 43000    69
# 44000    48
# Name: source, dtype: int64
